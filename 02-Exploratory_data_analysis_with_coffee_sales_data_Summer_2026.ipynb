# %% [markdown]
# <div align="left" style="background-color: #008080; padding: 20px 10px;">
# <h3><b>IDEAS - Institute of Data Engineering, Analytics and Science Foundation</b></h3>
# <p>Summer Internship Program 2026</p>
# <hr style="width:100%;">
# <h3><b>Project Title:</b> Exploratory data analysis with Coffee sales data and MNIST data clustering.</h3>
# <h4>Project Notebook</h4>
#
# <blockquote style="border-left: 4px solid #4285F4; padding-left: 15px;">
#   <strong>Created by:</strong> Koulika Paul<br>
#   <strong>Designation:</strong> Project Linked Associate Research Engineer in Statistics
# </blockquote>
# <hr style="width:100%;">
# </div>

# %% [markdown]
# ### Question 1: Import Libraries and Load Data (1 Mark)
#
# Import the `pandas` library as `pd`. Then, download the data `Coffe_sales.csv` from https://drive.google.com/drive/folders/1gieHICVDBbUKMZiSF4YRQMAJic-w50JM?usp=sharing and load into a DataFrame named `coffee_data` and display its first 5 rows.
#
# **Expected Output:** A table showing the first 5 rows of the coffee sales data.

# %%
import pandas as pd


file_id = "1GVqc66rN8sWNWTiDTFBfe3TL27ehcmbM"
url = f"https://drive.google.com/uc?export=download&id={file_id}"

# loading the CSV directly from Google Drive
coffee_data = pd.read_csv(url)

# Displaying the first 5 rows of the dataframe
coffee_data.head(5)
# Out:
#    hour_of_day cash_type  money    coffee_name Time_of_Day Weekday Month_name  \
# 0           10      card   38.7          Latte     Morning     Fri        Mar
# 1           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3           13      card   28.9      Americano   Afternoon     Fri        Mar
# 4           13      card   38.7          Latte   Afternoon     Fri        Mar
#
#    Weekdaysort  Monthsort        Date             Time
# 0            5          3  2024-03-01  10:15:50.520000
# 1            5          3  2024-03-01  12:19:22.539000
# 2            5          3  2024-03-01  12:20:18.089000
# 3            5          3  2024-03-01  13:46:33.006000
# 4            5          3  2024-03-01  13:48:14.626000

# %% [markdown]
# ### Question 2: Initial Data Inspection (2 Marks)
#
# Perform a basic inspection of the `coffee_data` DataFrame. Print the number of rows and columns, check for any duplicate rows, and find the total number of missing values in the entire dataset.
#
# **Expected Output:** A printout of the shape, the number of duplicate rows, and the total number of missing values.

# %%
# Number of rows and columns
rows, cols = coffee_data.shape
print(f"Number of rows   : {rows}")
print(f"Number of columns: {cols}")

# Duplicate rows
num_of_duplicates = coffee_data.duplicated().sum()
print(f"\nNumber of duplicate rows: {num_of_duplicates}")

# Total missing values
total_missing = coffee_data.isnull().sum().sum()
print(f"Total missing values    : {total_missing}")
# Out:
# Number of rows   : 3547
# Number of columns: 13
#
# Number of duplicate rows: 0
# Total missing values    : 0

# %% [markdown]
# ### Question 3: Basic Statistics (1 Marks)
#
# Generate and display the basic descriptive statistics for the numerical columns in the `coffee_data` DataFrame.
#
# **Hint:** Use the `.describe()` method on your DataFrame.
#
# **Expected Output:** A table showing count, mean, std, min, 25%, 50%, 75%, and max for the numerical columns.

# %%
# Basic descriptive statistics for the numerical columns

# For 'money' - all statistics (mean, std, quartiles, max, min) are valid
# For 'hour_of_day', 'Weekdaysort', 'Monthsort' - these are ordinal,
# so only min, max and quartiles are meaningful.  Mean and std are moments based measures that are not applicable for ordinal data

display(coffee_data[['money']].describe())
display(coffee_data[['hour_of_day', 'Weekdaysort', 'Monthsort']].describe().loc[['count', 'min', '25%', '50%', '75%', 'max']])
# Out:
#              money
# count  3547.000000
# mean     31.645216
# std       4.877754
# min      18.120000
# 25%      27.920000
# 50%      32.820000
# 75%      35.760000
# max      38.700000
#        hour_of_day  Weekdaysort  Monthsort
# count       3547.0       3547.0     3547.0
# min            6.0          1.0        1.0
# 25%           10.0          2.0        3.0
# 50%           14.0          4.0        7.0
# 75%           18.0          6.0       10.0
# max           22.0          7.0       12.0

# %% [markdown]
# ### Question 4: Data Type Conversion (1 Marks)
#
# The 'Date' column is currently an object. Convert it to a datetime object. Then, create two new columns: 'Month' (containing the month number) and 'Year' (containing the year as an integer). Finally, display the data types of all columns.
#
# **Expected Output:** A series listing each column and its updated data type.

# %%
coffee_data['Date'] = pd.to_datetime(coffee_data['Date'], format='%Y-%m-%d')

coffee_data['Month'] = coffee_data['Date'].dt.month
coffee_data['Year'] = coffee_data['Date'].dt.year.astype(int)

coffee_data.dtypes
# Out:
# hour_of_day             int64
# cash_type              object
# money                 float64
# coffee_name            object
# Time_of_Day            object
# Weekday                object
# Month_name             object
# Weekdaysort             int64
# Monthsort               int64
# Date           datetime64[ns]
# Time                   object
# Month                   int32
# Year                    int64
# dtype: object

# %% [markdown]
# ### Question 5: Data Aggregation and Analysis (5 Marks)
#
# Perform the following data analysis tasks:
# 1. **Average Sales per Year:** Calculate the average 'money' (sales) for each 'Year'. Group the data by the 'Year' column and then compute the mean of the 'money' column for each group.
# 2. **Maximum Sales by Month Name:** Find the maximum 'money' earned for each 'Month_name'. Display the result as a Pandas Series.
# 3. **Total Sales by Coffee Name:** Calculate the total 'money' (sum of sales) for each 'coffee_name'.
# 4. **Unique Coffee Types:** Determine how many unique types of coffee are present in the dataset. Print the unique coffee names as a list.
# 5. **Average Sales by Time of Day:** Find the average 'money' made during each 'Time_of_Day' (Morning, Afternoon, Night).
#
# **Expected Output:** Display the appropriate results for each step (e.g. Pandas Series and list) clearly.

# %%
# 1. Average Sales per Year
print("Data grouped by Year:")
display(coffee_data.sort_values('Year'))
print("\nAverage Sales per Year:")
display(coffee_data.groupby('Year')['money'].mean())

# 2. Maximum Sales by Month Name
print("\nMaximum Sales by Month Name:")
display (coffee_data.groupby(['Year', 'Monthsort','Month_name'])['money'].max())

# 3. Total Sales by Coffee Name
print("\nTotal Sales by Coffee Name:")
display(coffee_data.groupby('coffee_name')['money'].sum())

# 4. Unique Coffee Types
print("Number of unique coffee types:", coffee_data['coffee_name'].nunique())
print("Unique coffee names:", coffee_data['coffee_name'].unique().tolist())

# 5. Average Sales by Time of Day
print("\nAverage Sales by Time of Day:")
display(coffee_data.groupby('Time_of_Day')['money'].mean())
# Out:
# Data grouped by Year:
#       hour_of_day cash_type  money          coffee_name Time_of_Day Weekday  \
# 14             14      card  28.90            Americano   Afternoon     Sat
# 13             11      card  33.80  Americano with Milk     Morning     Sat
# 12             10      card  33.80  Americano with Milk     Morning     Sat
# 11             10      card  28.90            Americano     Morning     Sat
# 2603           19      card  35.76        Hot Chocolate       Night     Tue
# ...           ...       ...    ...                  ...         ...     ...
# 2608           14      card  25.96              Cortado   Afternoon     Thu
# 2607           14      card  25.96              Cortado   Afternoon     Thu
# 2606           13      card  35.76                Cocoa   Afternoon     Thu
# 2605           13      card  35.76                Cocoa   Afternoon     Thu
# 2604            9      card  30.86  Americano with Milk     Morning     Thu
#
#      Month_name  Weekdaysort  Monthsort       Date             Time  Month  \
# 14          Mar            6          3 2024-03-02  14:38:35.535000      3
# 13          Mar            6          3 2024-03-02  11:59:45.484000      3
# 12          Mar            6          3 2024-03-02  10:41:41.249000      3
# 11          Mar            6          3 2024-03-02  10:22:06.957000      3
# 2603        Dec            2         12 2024-12-31  19:08:38.899000     12
# ...         ...          ...        ...        ...              ...    ...
# 2608        Jan            4          1 2025-01-02  14:42:45.847000      1
# 2607        Jan            4          1 2025-01-02  14:41:10.594000      1
# 2606        Jan            4          1 2025-01-02  13:30:38.720000      1
# 2605        Jan            4          1 2025-01-02  13:29:40.128000      1
# 2604        Jan            4          1 2025-01-02  09:58:05.335000      1
#
#       Year
# 14    2024
# 13    2024
# 12    2024
# 11    2024
# 2603  2024
# ...    ...
# 2608  2025
# 2607  2025
# 2606  2025
# 2605  2025
# 2604  2025
#
# [3547 rows x 13 columns]
# Average Sales per Year:
# Year
# 2024    31.737634
# 2025    31.390011
# Name: money, dtype: float64
# Maximum Sales by Month Name:
# Year  Monthsort  Month_name
# 2024  3          Mar           38.70
#       4          Apr           38.70
#       5          May           37.72
#       6          Jun           37.72
#       7          Jul           37.72
#       8          Aug           32.82
#       9          Sep           35.76
#       10         Oct           35.76
#       11         Nov           35.76
#       12         Dec           35.76
# 2025  1          Jan           35.76
#       2          Feb           35.76
#       3          Mar           35.76
# Name: money, dtype: float64
# Total Sales by Coffee Name:
# coffee_name
# Americano              14650.26
# Americano with Milk    24751.12
# Cappuccino             17439.14
# Cocoa                   8521.16
# Cortado                 7384.86
# Espresso                2690.28
# Hot Chocolate           9933.46
# Latte                  26875.30
# Name: money, dtype: float64
# Number of unique coffee types: 8
# Unique coffee names: ['Latte', 'Hot Chocolate', 'Americano', 'Americano with Milk', 'Cocoa', 'Cortado', 'Espresso', 'Cappuccino']
#
# Average Sales by Time of Day:
# Time_of_Day
# Afternoon    31.643187
# Morning      30.422693
# Night        32.890904
# Name: money, dtype: float64

# %% [markdown]
# ### Question 6: Generate and Display Synthetic Data (3 Marks)
#
# Create a new, synthetic DataFrame named `synthetic_df`. It should have two columns: 'date' and 'value'. The 'date' column should contain 100 dates starting from '2023-01-01'. The 'value' column should contain 100 random numbers. Display the entire synthetic DataFrame.
#
# **Expected Output:** A 100x2 DataFrame with 'date' and 'value' columns.

# %%
import numpy as np

dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
values = np.random.randn(
Marks)
#
# Load the MNIST dataset using `sklearn.datasets.load_digits`. Separate the dataset into features (`X`) and target labels (`y`).
# Print the shape of the features and the target arrays.
#
# **Expected Output:** The shape of `X` and `y`.

# %%
from sklearn.datasets import load_digits

digits = load_digits()

X = digits.data
y = digits.target

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (1797, 64)
# Shape of y: (1797,)

# %% [markdown]
# ### Question 8: K-Means Clustering (5 Marks)
#
# Import `KMeans` from `sklearn.cluster`. Initialize and fit the K-Means clustering model on the MNIST features (`X`).
# Since we know there are 10 digits (0-9), set the number of clusters to 10. Assign the cluster labels to a variable `kmeans_labels`.
#
# **Expected Output:** A successfully fitted K-Means model and the cluster labels array.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=10, random_state=42, n_init=10)
kmeans.fit(X)

kmeans_labels = kmeans.labels_

print("K-Means model fitted successfully!")
print("Cluster labels array:", kmeans_labels)
print("Shape of cluster labels:", kmeans_labels.shape)
# Out:
# K-Means model fitted successfully!
# Cluster labels array: [1 3 3 ... 3 8 8]
# Shape of cluster labels: (1797,)

# %% [markdown]
# ### Question 9: F1 Score Evaluation for Clustering (5 Marks)
#
# Evaluate the clustering performance using the F1 score. Since K-Means assigns arbitrary cluster labels, you will first need to map each cluster label to the most frequent true label in that cluster.
# After mapping the labels, calculate and print the macro-averaged F1 score using `sklearn.metrics.f1_score`.
#
# **Expected Output:** The calculated F1 score of the clustering.

# %%
import numpy as np
from sklearn.metrics import f1_score

# Map each cluster to the most frequent true label
label_map = {}
for cluster in range(10):
    true_labels_in_cluster = y[kmeans_labels == cluster]
    label_map[cluster] = int(np.bincount(true_labels_in_cluster).argmax())

print("Cluster to Digit mapping:")
for cluster, digit in label_map.items():
    print(f"  Cluster {cluster} -> Digit {digit}")

# Apply mapping
mapped_labels = np.array([label_map[label] for label in kmeans_labels])

# F1 score
f1 = f1_score(y, mapped_labels, average='macro')
print(f"\nMacro-averaged F1 Score: {round(f1, 4)}")
# Out:
# Cluster to Digit mapping:
#   Cluster 0 -> Digit 2
#   Cluster 1 -> Digit 0
#   Cluster 2 -> Digit 1
#   Cluster 3 -> Digit 8
#   Cluster 4 -> Digit 7
#   Cluster 5 -> Digit 6
#   Cluster 6 -> Digit 3
#   Cluster 7 -> Digit 5
#   Cluster 8 -> Digit 9
#   Cluster 9 -> Digit 4
#
# Macro-averaged F1 Score: 0.7895

# %% [markdown]
# ### Question 10: Confusion Matrix for Clustering (3 Marks)
#
# Generate and display the confusion matrix comparing your mapped cluster labels (from Question 9) to the true labels (`y`). Use `confusion_matrix` from `sklearn.metrics`. This helps evaluate how well your clusters align with the actual digit classes without requiring visual plotting.
#
# **Expected Output:** A 10x10 confusion matrix printed as an array or a Pandas DataFrame.

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y, mapped_labels)

cm_df = pd.DataFrame(
    cm,
    index=[f"True {i}" for i in range(10)],
    columns=[f"Pred {i}" for i in range(10)]
)

print("Confusion Matrix:")
display(cm_df)
# Out:
# Confusion Matrix:
#         Pred 0  Pred 1  Pred 2  Pred 3  Pred 4  Pred 5  Pred 6  Pred 7  \
# True 0     177       0       0       0       1       0       0       0
# True 1       0      55      24       1       0       1       2       0
# True 2       1       2     148      13       0       0       0       3
# True 3       0       0       1     155       0       2       0       7
# True 4       0       3       0       0     166       0       0       8
# True 5       0       0       0       2       1     137       1       0
# True 6       1       1       0       0       0       0     177       0
# True 7       0       2       0       0       0       5       0     170
# True 8       0       6       3       4       0       6       2       3
# True 9       0      20       0       6       0       6       0       7
#
#         Pred 8  Pred 9
# True 0       0       0
# True 1      99       0
# True 2       8       2
# True 3       7      11
# True 4       4       0
# True 5       0      41
# True 6       2       0
# True 7       2       0
# True 8     102      48
# True 9       2     139
